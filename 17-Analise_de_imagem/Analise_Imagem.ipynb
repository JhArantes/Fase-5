# %% [markdown]
# # Processamento de Imagens

# %% [markdown]
# ## Modulos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cv2
from PIL import Image
import imutils

# %% [markdown]
# ### Carregar Imagens

# %%
imagem = np.array(Image.open('../17-Analise_de_imagem/IMGs/scarllet.png'))

# %%
plt.figure(figsize = (5,5))
plt.imshow(imagem)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %% [markdown]
# - Rotacionar

# %%
angulo = -90
img_rotated = imutils.rotate_bound(imagem, angle=angulo)
plt.imshow(img_rotated)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(639.5), np.float64(639.5), np.float64(-0.5))

# %% [markdown]
# - Mudar Escala

# %%
img_gc = Image.open('../17-Analise_de_imagem/IMGs/scarllet.png').convert('LA')

# %%
plt.imshow(img_gc)

# %% [markdown]
# - Propriedades da Imagem

# %%
type(imagem)
# Out:
# numpy.ndarray

# %%
imagem.shape
# Out:
# (640, 640, 3)

# %%
imagem.ndim
# Out:
# 3

# %%
imagem.size, 640*640*3
# Out:
# (1228800, 1228800)

# %% [markdown]
# ### Dividir as camadas RGB

# %%
plt.title('Escala R')
plt.ylabel('Altura {}'.format(imagem.shape[0]))
plt.xlabel('Largura {}'.format(imagem.shape[1]))
plt.imshow(imagem[:,:,0])

# %%
imagem[:,:,0]
# Out:
# array([[73, 74, 74, ..., 32, 30, 30],
#        [74, 74, 75, ..., 35, 33, 32],
#        [74, 74, 75, ..., 39, 38, 37],
#        ...,
#        [ 7,  7,  8, ...,  9,  9,  9],
#        [ 5,  6,  8, ...,  9,  9,  9],
#        [ 4,  5,  8, ...,  9,  9,  9]], shape=(640, 640), dtype=uint8)

# %%
plt.title('Escala R')
plt.ylabel('Altura {}'.format(imagem.shape[0]))
plt.xlabel('Largura {}'.format(imagem.shape[1]))
plt.imshow(imagem[:,:,1])

# %%
plt.title('Escala R')
plt.ylabel('Altura {}'.format(imagem.shape[0]))
plt.xlabel('Largura {}'.format(imagem.shape[1]))
plt.imshow(imagem[:,:,2])
